# %% [markdown]
#    # Linear Regression and Web Scraping Project MVP

# %% [markdown]
# ### Introduction
#
# Our goal is building a model form carvago.com to predict car sales price.
# We were able to do a web scraping from the website and added the following futures Kms_driven, Price, Transmission, Fuel type and First_ registration.
#
# ### Strategy:
#
# 1- Collect data from (https://carvago.com/).
# 2- Data cleaning and preparation.
# 3- Using the best linear regression model.
#
# ### Tools:
#
# Python with Jupiter Notebook.
#
# Libraries: NumPy, Pandas, BeautifulSoup , statsmodels , sklearn , matplotlib and patsy

# %%
import pickle
with open('mylastandlastdataframe.pickle', 'rb') as to_read:
    df=pickle.load(to_read)
df
# Out:
#                                              Car_Name  Price_€  km_Driven  \
# 0                      Volkswagen Caddy 2.0 TDI 75 kW    10699     134572
# 1                                      BMW 120 141 kW    44449       5413
# 2                                      BMW 640 250 kW    52899      27656
# 3                  Renault ZOE  70 kW without battery     9599      30200
# 4      Mercedes-Benz E 63 AMG E T S 4Matic MCT 430 kW    47849      25000
# ...                                               ...      ...        ...
# 5955                Renault Kadjar TCe 140 GPF 103 kW    21399       7990
# 5956                            Mazda CX-5 165 121 kW    28499       4000
# 5957                  Volkswagen T-Roc 1.5 TSI 110 kW    29599        500
# 5958  Kia Optima 2.0 GDI Plug-In Hybrid Spirit 113 kW    31699      10500
# 5959      Audi A4 Avant 45 TFSI S tronic sport 180 kW    32249      24679
#
#      First_Registration  Power_kW  Automatic  Manual  Diesel  Electric  \
# ...
